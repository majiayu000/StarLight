# %% [markdown]
# ### LLM security is an area that we need to pay attention.

# %%
import os

# %%
from llama_index.llama_pack import download_llama_pack


LlamaGuardModeratorPack = download_llama_pack(
    llama_pack_class="LlamaGuardModeratorPack",
    download_dir="llama_guard_moderator_pack",
)

# %%
os.environ["HUGGINGFACE_ACCESS_TOKEN"] = "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"

# %%
llamaguard_pack = LlamaGuardModeratorPack()
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /Users/lifcc/.cache/huggingface/token
# Login successful
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/huggingface_hub/utils/_errors.py:270, in hf_raise_for_status(response, endpoint_name)
#     269 try:
# --> 270     response.raise_for_status()
#     271 except HTTPError as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# ...
