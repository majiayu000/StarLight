# %%
from langchain.chat_models import AzureChatOpenAI

# Use azure api

BASE_URL = "https://conslearn.openai.azure.com"
API_KEY = "fcb9227a52b640d387bfe43097ebaa25"
DEPLOYMENT_NAME = 'gpt35'

llm = AzureChatOpenAI(
    openai_api_base=BASE_URL,
    openai_api_version="2023-09-01-preview",
    deployment_name=DEPLOYMENT_NAME,
    openai_api_key=API_KEY,
    openai_api_type="azure",
    temperature=0,
    verbose=True
)

# %%
# test for azure
from langchain.callbacks import get_openai_callback
from langchain.schema import HumanMessage

with get_openai_callback() as cb:
    llm(
        [
            HumanMessage(
                content="Translate this sentence from English to French. I love programming."
            )
        ]
    )
    print(
        f"Total Cost (USD): ${format(cb.total_cost, '.6f')}"
    )  # without specifying the model version, flat-rate 0.002 USD per 1k input and output tokens is used
# Out:
# [llm/start] [1:llm:AzureChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Translate this sentence from English to French. I love programming."
#   ]
# }
# [llm/end] [1:llm:AzureChatOpenAI] [1.57s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "J'adore la programmation.",
#         "generation_info": {
#           "finish_reason": "stop"
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "J'adore la programmation.",
#             "additional_kwargs": {}
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "prompt_tokens": 19,
#       "completion_tokens": 8,
#       "total_tokens": 27
#     },
#     "model_name": "gpt-35-turbo"
#   },
#   "run": null
# }
# Total Cost (USD): $0.000044

# %%
from langchain.agents import tool

@tool
def get_word_length(word: str) -> int:
    """Returns the length of a word."""
    return len(word)

tools = [get_word_length]

# %%
from langchain.globals import set_debug, set_verbose

set_debug(False)

# %%
from langchain.prompts import ChatPromptTemplate, MessagesPlaceholder
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are very powerful assistant, but bad at calculating lengths of words."),
    ("user", "{input}"),
    MessagesPlaceholder(variable_name="agent_scratchpad"),
])

# %%
from langchain.tools.render import format_tool_to_openai_function
llm_with_tools = llm.bind(
    functions=[format_tool_to_openai_function(t) for t in tools]
)

# %%
# LCEL stands for LangChain Expression Language. It is a language used in the LangChain framework 
# for composing and executing different components such as prompt templates, language models, and 
# output parsers. LCEL provides a way to easily combine these components using a pipeline-like syntax.
from langchain.agents.format_scratchpad import format_to_openai_functions
from langchain.agents.output_parsers import OpenAIFunctionsAgentOutputParser
agent = {
    "input": lambda x: x["input"],
    "agent_scratchpad": lambda x: format_to_openai_functions(x['intermediate_steps'])
} | prompt | llm_with_tools | OpenAIFunctionsAgentOutputParser()

# %%
st = {
    "input": lambda x: x["input"],
    "agent_scratchpad": lambda x: format_to_openai_functions(x['intermediate_steps'])
} | prompt |llm_with_tools

# %%
set_debug(True)
set_verbose(True)
agent.invoke({"input": "When is now?",
              "intermediate_steps": []})
# Out:
# [chain/start] [1:chain:RunnableSequence] Entering Chain run with input:
# {
#   "input": "When is now?",
#   "intermediate_steps": []
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableParallel] Entering Chain run with input:
# {
#   "input": "When is now?",
#   "intermediate_steps": []
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableParallel > 3:chain:<lambda>] Entering Chain run with input:
# {
#   "input": "When is now?",
#   "intermediate_steps": []
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableParallel > 3:chain:<lambda>] s] Exiting Chain run with output:
# {
#   "output": "When is now?"
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableParallel > 4:chain:<lambda>] Entering Chain run with input:
# {
#   "input": "When is now?",
#   "intermediate_steps": []
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableParallel > 4:chain:<lambda>] s] Exiting Chain run with output:
# {
#   "output": []
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableParallel] s] Exiting Chain run with output:
# {
#   "input": "When is now?",
#   "agent_scratchpad": []
# }
# [chain/start] [1:chain:RunnableSequence > 5:prompt:ChatPromptTemplate] Entering Prompt run with input:
# {
#   "input": "When is now?",
#   "agent_scratchpad": []
# }
# [chain/end] [1:chain:RunnableSequence > 5:prompt:ChatPromptTemplate] s] Exiting Prompt run with output:
# {
#   "lc": 1,
#   "type": "constructor",
#   "id": [
#     "langchain",
#     "prompts",
#     "chat",
#     "ChatPromptValue"
#   ],
#   "kwargs": {
#     "messages": [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "messages",
#           "SystemMessage"
#         ],
#         "kwargs": {
#           "content": "You are very powerful assistant, but bad at calculating lengths of words.",
#           "additional_kwargs": {}
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "messages",
#           "HumanMessage"
#         ],
#         "kwargs": {
#           "content": "When is now?",
#           "additional_kwargs": {}
#         }
#       }
#     ]
#   }
# }
# [llm/start] [1:chain:RunnableSequence > 6:llm:AzureChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are very powerful assistant, but bad at calculating lengths of words.\nHuman: When is now?"
#   ]
# }
# [llm/end] [1:chain:RunnableSequence > 6:llm:AzureChatOpenAI] s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "Now is the present moment. It is the current time or the time at which something is happening.",
#         "generation_info": {
#           "finish_reason": "stop"
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "Now is the present moment. It is the current time or the time at which something is happening.",
#             "additional_kwargs": {}
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "prompt_tokens": 75,
#       "completion_tokens": 21,
#       "total_tokens": 96
#     },
#     "model_name": "gpt-35-turbo"
#   },
#   "run": null
# }
# [chain/start] [1:chain:RunnableSequence > 7:parser:OpenAIFunctionsAgentOutputParser] Entering Parser run with input:
# [inputs]
# message is content='Now is the present moment. It is the current time or the time at which something is happening.'
# func tion message is content='Now is the present moment. It is the current time or the time at which something is happening.'
# [chain/end] [1:chain:RunnableSequence > 7:parser:OpenAIFunctionsAgentOutputParser] s] Exiting Parser run with output:
# {
#   "lc": 1,
#   "type": "constructor",
#   "id": [
#     "langchain",
#     "schema",
#     "agent",
#     "AgentFinish"
#   ],
#   "kwargs": {
#     "return_values": {
#       "output": "Now is the present moment. It is the current time or the time at which something is happening."
#     },
#     "log": "Now is the present moment. It is the current time or the time at which something is happening."
#   }
# }
# [chain/end] [1:chain:RunnableSequence] s] Exiting Chain run with output:
# [outputs]
# AgentFinish(return_values={'output': 'Now is the present moment. It is the current time or the time at which something is happening.'}, log='Now is the present moment. It is the current time or the time at which something is happening.')

# %%
agent.invoke({
    "input": "how many letters in the word educa?",
    "intermediate_steps": []
})
# Out:
# [chain/start] [1:chain:RunnableSequence] Entering Chain run with input:
# {
#   "input": "how many letters in the word educa?",
#   "intermediate_steps": []
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableParallel] Entering Chain run with input:
# {
#   "input": "how many letters in the word educa?",
#   "intermediate_steps": []
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableParallel > 3:chain:<lambda>] Entering Chain run with input:
# {
#   "input": "how many letters in the word educa?",
#   "intermediate_steps": []
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableParallel > 3:chain:<lambda>] s] Exiting Chain run with output:
# {
#   "output": "how many letters in the word educa?"
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableParallel > 4:chain:<lambda>] Entering Chain run with input:
# {
#   "input": "how many letters in the word educa?",
#   "intermediate_steps": []
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableParallel > 4:chain:<lambda>] s] Exiting Chain run with output:
# {
#   "output": []
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableParallel] s] Exiting Chain run with output:
# {
#   "input": "how many letters in the word educa?",
#   "agent_scratchpad": []
# }
# [chain/start] [1:chain:RunnableSequence > 5:prompt:ChatPromptTemplate] Entering Prompt run with input:
# {
#   "input": "how many letters in the word educa?",
#   "agent_scratchpad": []
# }
# [chain/end] [1:chain:RunnableSequence > 5:prompt:ChatPromptTemplate] s] Exiting Prompt run with output:
# {
#   "lc": 1,
#   "type": "constructor",
#   "id": [
#     "langchain",
#     "prompts",
#     "chat",
#     "ChatPromptValue"
#   ],
#   "kwargs": {
#     "messages": [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "messages",
#           "SystemMessage"
#         ],
#         "kwargs": {
#           "content": "You are very powerful assistant, but bad at calculating lengths of words.",
#           "additional_kwargs": {}
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "messages",
#           "HumanMessage"
#         ],
#         "kwargs": {
#           "content": "how many letters in the word educa?",
#           "additional_kwargs": {}
#         }
#       }
#     ]
#   }
# }
# [llm/start] [1:chain:RunnableSequence > 6:llm:AzureChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are very powerful assistant, but bad at calculating lengths of words.\nHuman: how many letters in the word educa?"
#   ]
# }
# [llm/end] [1:chain:RunnableSequence > 6:llm:AzureChatOpenAI] s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "",
#         "generation_info": {
#           "finish_reason": "function_call"
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "",
#             "additional_kwargs": {
#               "function_call": {
#                 "name": "get_word_length",
#                 "arguments": "{\n  \"word\": \"educa\"\n}"
#               }
#             }
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "prompt_tokens": 80,
#       "completion_tokens": 17,
#       "total_tokens": 97
#     },
#     "model_name": "gpt-35-turbo"
#   },
#   "run": null
# }
# [chain/start] [1:chain:RunnableSequence > 7:parser:OpenAIFunctionsAgentOutputParser] Entering Parser run with input:
# [inputs]
# message is content='' additional_kwargs={'function_call': {'name': 'get_word_length', 'arguments': '{\n  "word": "educa"\n}'}}
# func tion message is content='' additional_kwargs={'function_call': {'name': 'get_word_length', 'arguments': '{\n  "word": "educa"\n}'}}
# [chain/end] [1:chain:RunnableSequence > 7:parser:OpenAIFunctionsAgentOutputParser] s] Exiting Parser run with output:
# {
#   "lc": 1,
#   "type": "constructor",
#   "id": [
#     "langchain",
#     "schema",
#     "agent",
#     "AgentActionMessageLog"
#   ],
#   "kwargs": {
#     "tool": "get_word_length",
#     "tool_input": {
#       "word": "educa"
#     },
#     "log": "\nInvoking: `get_word_length` with `{'word': 'educa'}`\n\n\n",
#     "message_log": [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "messages",
#           "AIMessage"
#         ],
#         "kwargs": {
#           "content": "",
#           "additional_kwargs": {
#             "function_call": {
#               "name": "get_word_length",
#               "arguments": "{\n  \"word\": \"educa\"\n}"
#             }
#           }
#         }
#       }
#     ]
#   }
# }
# [chain/end] [1:chain:RunnableSequence] s] Exiting Chain run with output:
# [outputs]
# AgentActionMessageLog(tool='get_word_length', tool_input={'word': 'educa'}, log="\nInvoking: `get_word_length` with `{'word': 'educa'}`\n\n\n", message_log=[AIMessage(content='', additional_kwargs={'function_call': {'name': 'get_word_length', 'arguments': '{\n  "word": "educa"\n}'}})])

# %%
from langchain.schema.agent import AgentFinish
intermediate_steps = []
while True:
    output = agent.invoke({
        "input": "how many letters in the word educa?",
        "intermediate_steps": intermediate_steps
    })
    if isinstance(output, AgentFinish):
        final_result = output.return_values["output"]
        break
    else:
        print(output.tool, output.tool_input)
        tool = {
            "get_word_length": get_word_length
        }[output.tool]
        observation = tool.run(output.tool_input)
        intermediate_steps.append((output, observation))
print(final_result)
# Out:
# [chain/start] [1:chain:RunnableSequence] Entering Chain run with input:
# {
#   "input": "how many letters in the word educa?",
#   "intermediate_steps": []
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableParallel] Entering Chain run with input:
# {
#   "input": "how many letters in the word educa?",
#   "intermediate_steps": []
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableParallel > 3:chain:<lambda>] Entering Chain run with input:
# {
#   "input": "how many letters in the word educa?",
#   "intermediate_steps": []
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableParallel > 3:chain:<lambda>] s] Exiting Chain run with output:
# {
#   "output": "how many letters in the word educa?"
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableParallel > 4:chain:<lambda>] Entering Chain run with input:
# {
#   "input": "how many letters in the word educa?",
#   "intermediate_steps": []
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableParallel > 4:chain:<lambda>] s] Exiting Chain run with output:
# {
#   "output": []
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableParallel] s] Exiting Chain run with output:
# {
#   "input": "how many letters in the word educa?",
#   "agent_scratchpad": []
# }
# [chain/start] [1:chain:RunnableSequence > 5:prompt:ChatPromptTemplate] Entering Prompt run with input:
# {
#   "input": "how many letters in the word educa?",
#   "agent_scratchpad": []
# }
# [chain/end] [1:chain:RunnableSequence > 5:prompt:ChatPromptTemplate] s] Exiting Prompt run with output:
# {
#   "lc": 1,
#   "type": "constructor",
#   "id": [
#     "langchain",
#     "prompts",
#     "chat",
#     "ChatPromptValue"
#   ],
#   "kwargs": {
#     "messages": [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "messages",
#           "SystemMessage"
#         ],
#         "kwargs": {
#           "content": "You are very powerful assistant, but bad at calculating lengths of words.",
#           "additional_kwargs": {}
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "messages",
#           "HumanMessage"
#         ],
#         "kwargs": {
#           "content": "how many letters in the word educa?",
#           "additional_kwargs": {}
#         }
#       }
#     ]
#   }
# }
# [llm/start] [1:chain:RunnableSequence > 6:llm:AzureChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are very powerful assistant, but bad at calculating lengths of words.\nHuman: how many letters in the word educa?"
#   ]
# }
# [llm/end] [1:chain:RunnableSequence > 6:llm:AzureChatOpenAI] s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "",
#         "generation_info": {
#           "finish_reason": "function_call"
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "",
#             "additional_kwargs": {
#               "function_call": {
#                 "name": "get_word_length",
#                 "arguments": "{\n  \"word\": \"educa\"\n}"
#               }
#             }
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "prompt_tokens": 80,
#       "completion_tokens": 17,
#       "total_tokens": 97
#     },
#     "model_name": "gpt-35-turbo"
#   },
#   "run": null
# }
# [chain/start] [1:chain:RunnableSequence > 7:parser:OpenAIFunctionsAgentOutputParser] Entering Parser run with input:
# [inputs]
# message is content='' additional_kwargs={'function_call': {'name': 'get_word_length', 'arguments': '{\n  "word": "educa"\n}'}}
# func tion message is content='' additional_kwargs={'function_call': {'name': 'get_word_length', 'arguments': '{\n  "word": "educa"\n}'}}
# [chain/end] [1:chain:RunnableSequence > 7:parser:OpenAIFunctionsAgentOutputParser] s] Exiting Parser run with output:
# {
#   "lc": 1,
#   "type": "constructor",
#   "id": [
#     "langchain",
#     "schema",
#     "agent",
#     "AgentActionMessageLog"
#   ],
#   "kwargs": {
#     "tool": "get_word_length",
#     "tool_input": {
#       "word": "educa"
#     },
#     "log": "\nInvoking: `get_word_length` with `{'word': 'educa'}`\n\n\n",
#     "message_log": [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "messages",
#           "AIMessage"
#         ],
#         "kwargs": {
#           "content": "",
#           "additional_kwargs": {
#             "function_call": {
#               "name": "get_word_length",
#               "arguments": "{\n  \"word\": \"educa\"\n}"
#             }
#           }
#         }
#       }
#     ]
#   }
# }
# [chain/end] [1:chain:RunnableSequence] s] Exiting Chain run with output:
# [outputs]
# get_word_length {'word': 'educa'}
# [tool/start] [1:tool:get_word_length] Entering Tool run with input:
# "{'word': 'educa'}"
# [tool/end] [1:tool:get_word_length] s] Exiting Tool run with output:
# "5"
# [chain/start] [1:chain:RunnableSequence] Entering Chain run with input:
# [inputs]
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableParallel] Entering Chain run with input:
# [inputs]
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableParallel > 3:chain:<lambda>] Entering Chain run with input:
# [inputs]
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableParallel > 3:chain:<lambda>] s] Exiting Chain run with output:
# {
#   "output": "how many letters in the word educa?"
# }
# [chain/start] [1:chain:RunnableSequence > 2:chain:RunnableParallel > 4:chain:<lambda>] Entering Chain run with input:
# [inputs]
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableParallel > 4:chain:<lambda>] s] Exiting Chain run with output:
# {
#   "output": [
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "messages",
#         "AIMessage"
#       ],
#       "kwargs": {
#         "content": "",
#         "additional_kwargs": {
#           "function_call": {
#             "name": "get_word_length",
#             "arguments": "{\n  \"word\": \"educa\"\n}"
#           }
#         }
#       }
#     },
#     {
#       "lc": 1,
#       "type": "constructor",
#       "id": [
#         "langchain",
#         "schema",
#         "messages",
#         "FunctionMessage"
#       ],
#       "kwargs": {
#         "name": "get_word_length",
#         "content": "5"
#       }
#     }
#   ]
# }
# [chain/end] [1:chain:RunnableSequence > 2:chain:RunnableParallel] s] Exiting Chain run with output:
# [outputs]
# [chain/start] [1:chain:RunnableSequence > 5:prompt:ChatPromptTemplate] Entering Prompt run with input:
# [inputs]
# [chain/end] [1:chain:RunnableSequence > 5:prompt:ChatPromptTemplate] s] Exiting Prompt run with output:
# {
#   "lc": 1,
#   "type": "constructor",
#   "id": [
#     "langchain",
#     "prompts",
#     "chat",
#     "ChatPromptValue"
#   ],
#   "kwargs": {
#     "messages": [
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "messages",
#           "SystemMessage"
#         ],
#         "kwargs": {
#           "content": "You are very powerful assistant, but bad at calculating lengths of words.",
#           "additional_kwargs": {}
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "messages",
#           "HumanMessage"
#         ],
#         "kwargs": {
#           "content": "how many letters in the word educa?",
#           "additional_kwargs": {}
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "messages",
#           "AIMessage"
#         ],
#         "kwargs": {
#           "content": "",
#           "additional_kwargs": {
#             "function_call": {
#               "name": "get_word_length",
#               "arguments": "{\n  \"word\": \"educa\"\n}"
#             }
#           }
#         }
#       },
#       {
#         "lc": 1,
#         "type": "constructor",
#         "id": [
#           "langchain",
#           "schema",
#           "messages",
#           "FunctionMessage"
#         ],
#         "kwargs": {
#           "name": "get_word_length",
#           "content": "5"
#         }
#       }
#     ]
#   }
# }
# [llm/start] [1:chain:RunnableSequence > 6:llm:AzureChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "System: You are very powerful assistant, but bad at calculating lengths of words.\nHuman: how many letters in the word educa?\nAI: {'name': 'get_word_length', 'arguments': '{\\n  \"word\": \"educa\"\\n}'}\nFunction: 5"
#   ]
# }
# [llm/end] [1:chain:RunnableSequence > 6:llm:AzureChatOpenAI] s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "There are 5 letters in the word \"educa\".",
#         "generation_info": {
#           "finish_reason": "stop"
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "There are 5 letters in the word \"educa\".",
#             "additional_kwargs": {}
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "prompt_tokens": 107,
#       "completion_tokens": 13,
#       "total_tokens": 120
#     },
#     "model_name": "gpt-35-turbo"
#   },
#   "run": null
# }
# [chain/start] [1:chain:RunnableSequence > 7:parser:OpenAIFunctionsAgentOutputParser] Entering Parser run with input:
# [inputs]
# message is content='There are 5 letters in the word "educa".'
# func tion message is content='There are 5 letters in the word "educa".'
# [chain/end] [1:chain:RunnableSequence > 7:parser:OpenAIFunctionsAgentOutputParser] s] Exiting Parser run with output:
# {
#   "lc": 1,
#   "type": "constructor",
#   "id": [
#     "langchain",
#     "schema",
#     "agent",
#     "AgentFinish"
#   ],
#   "kwargs": {
#     "return_values": {
#       "output": "There are 5 letters in the word \"educa\"."
#     },
#     "log": "There are 5 letters in the word \"educa\"."
#   }
# }
# [chain/end] [1:chain:RunnableSequence] s] Exiting Chain run with output:
# [outputs]
# There are 5 letters in the word "educa".

# %%
for step in agent["agent_scratchpad"]:
    print(f"Input: {step['input']}")
    print(f"Output: {step['output']}")
    print()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\learn\star\StarLight\MachineLearning\langchain\agent\test_prompt.ipynb 单元格 12 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/learn/star/StarLight/MachineLearning/langchain/agent/test_prompt.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> for step in agent["agent_scratchpad"]:
#       <a href='vscode-notebook-cell:/c%3A/learn/star/StarLight/MachineLearning/langchain/agent/test_prompt.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a>     print(f"Input: {step['input']}")
#       <a href='vscode-notebook-cell:/c%3A/learn/star/StarLight/MachineLearning/langchain/agent/test_prompt.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a>     print(f"Output: {step['output']}")
#
# TypeError: 'RunnableSequence' object is not subscriptable

# %%
input_data = agent("input")
scratchpad_data = agent("agent_scratchpad")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\learn\star\StarLight\MachineLearning\langchain\agent\test_prompt.ipynb 单元格 13 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/learn/star/StarLight/MachineLearning/langchain/agent/test_prompt.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> input_data = agent("input")
#       <a href='vscode-notebook-cell:/c%3A/learn/star/StarLight/MachineLearning/langchain/agent/test_prompt.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> scratchpad_data = agent("agent_scratchpad")
#
# TypeError: 'RunnableSequence' object is not callable
