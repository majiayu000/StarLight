# %%
from os import environ

MILVUS_HOST = "127.0.0.1"
MILVUS_PORT = "19530"
OPENAI_API_KEY = "sk-**" # example: "sk-xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx"
MILVUS_USER = "root"
MILVUS_PASSWORD = "YOURPASSWORD"

environ["OPENAI_API_KEY"] = OPENAI_API_KEY

# %%
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import Milvus
from langchain.document_loaders import WebBaseLoader
from langchain.text_splitter import CharacterTextSplitter

# %%
embeddings = OpenAIEmbeddings()

# %%
MILVUS_HOST = ""
MILVUS_PORT = "19530"
MILVUS_USER = ""
MILVUS_PASSWORD = ""

# %%
vector_db = Milvus(
    embeddings,
    collection_name= "computer",
    connection_args={"host": MILVUS_HOST, "port": MILVUS_PORT, "user": MILVUS_USER, "password": MILVUS_PASSWORD},
)

# %%
query = "pandas如何修改行列名"
docs = vector_db.similarity_search_with_score(query)

print(docs)
# Out:
# [(Document(page_content="#绘制插值后数据 3D曲面\nplt.show ()大学计算机基础\n（理科类）\n北京航空航天大学第13讲  数据分析\n与GUI设计自学内容2自学内容\n自学课件“《大学计算机基础》 -第13讲 数据分析与 GUI设计【自学内容 】”中\n①“13.1.2  利用Pandas进行数据分析 ”中\n4、修改行列名\n5、加入数据\n②“13.2.2  Tkinter 常用组件的使用方法 ”中\n        一、用 Label组件创建标签\n        三、用 Checkbutton 组件创建复选框 （自学教材）\n③“13.2.3  组件的几何布局” 中\n         一、利用pack方法布局组件\n         三、利用place方法布局组件 （【拓展】上网查阅资料，自学 ）313.1  数据分析\n◆13.1.1  数据分析概述\n◆13.1.2  利用Pandas进行数据分析4、修改行列名 【例13.2】\n44、修改行列名\n◆有时需要修改 DataFrame 的行名或列名\ndf1 = pd.DataFrame ({\n'col1':[11,21,31,np.nan,51],\n'col2':[12, 22, 32, 42, np.nan ],\n'col3':[13, 23, 33, 43, 53]})\n#修改行索引\ndf1.index = ['a0','a1','a2','a3','a4']\n#修改列索引\ndf1.columns = [' a','b','c '] \n方法一 修改DataFrame 的index或columns 属性值\n例13.2-修改DataFrame 的行列名 .py4、修改行列名（续1）\n5df2 = pd.DataFrame ({'A': [1, 2, 3], 'B': [4, 5, 6]})\n#（1）指定 columns参数修改列索引\ndf2.rename (columns ={‘A’: ‘a’, ‘B’: ‘c’}, inplace =True )\n方法二 使用pandas.DataFrame. rename ()函数\n◆rename函数是专门修改 DataFrame 坐标轴索引的函数。\n◆优点：可以选择性地修改某行某列的索引\n◆inplace参数默认为 False，不在原处修改数\n据，返回一个新的 DataFrame", metadata={}), 0.3246510624885559), (Document(page_content="df2.rename (columns ={‘A’: ‘a’, ‘B’: ‘c’}, inplace =True )\n方法二 使用pandas.DataFrame. rename ()函数\n◆rename函数是专门修改 DataFrame 坐标轴索引的函数。\n◆优点：可以选择性地修改某行某列的索引\n◆inplace参数默认为 False，不在原处修改数\n据，返回一个新的 DataFrame\n◆当需要修改原数据表 时，必须设置\ninplace =True4、修改行列名（续2）\n6#（2）指定 index参数修改行索引\ndf2.rename( index={0: 'x', 1: 'y', 2: 'z'} ,inplace =True)\n#（3）指定 axis参数，将列索引修改为大写字母\ndf2.rename( str.upper , axis='columns' ,inplace =True) \n#（4）指定 axis参数，修改行索引\ndf2.rename ({'y': ' yy', 'z': ' zz'}, axis='index' ,inplace =True)\n5、加入数据\n75、加入数据\n◆可以使用 append方法将一个数据表中的所有 行添加到另一个数据表的末尾，\n返回一个 新的数据表 （原数据表 不变）\n        原数据表 .append(要添加的数据表 ) \n【例】append_result= df1.append(df2)   #将df2中的所有行添加到 df1的末尾\nappend方法\nconcat方法◆也可以使用 concat方法将一个数据表中的 所有行或列（默认参数 axis=0，\n表示按行添加； axis=1表示按列添加）添加到另一个数据表的末尾，返回\n一个新的数据表\npd.concat([ 原数据表 , 要添加的数据表 ],axis=0< 或axis=1>) \n【例】concat_result= pd.concat([df1, df2],axis=1) \n#将df2中的所有列添加到 df1的末尾未来 pandas版本可\n能移除该方法【例13.3】加入数据示例\n8【例13.3】加入数据。分别创建 两个二维数据表df1、df2，列索引为 学号、数学成绩 ，行\n索引分别为 0~3、4~7。", metadata={}), 0.35712718963623047), (Document(page_content='data3={\'学号 \': [1001,1002,1003,1004,1005,1006,1007,1008], \' 语文成绩 \': [62,80,85,70,95,80,81,89]}\ndf3 = pd.DataFrame (data3) \n#将df3中的所有列添加到 append_result 的末尾（行数应该相同）。 axis=1表示沿 1轴连接，即 按列添加\nconcat_result =pd.concat ([append_result , df3],axis=1) \nprint(" concat_result ：","\\n",concat_result )\nconcat_result.to_excel (“成绩单 .xlsx")            #写入 Excel文件例13.3-加入数据 .py\n或者 df1 = pd.DataFrame (data1,\nindex= range(4) )  【例13.3】加入数据后结果\n10（1）原数据表\n◼append方法和concat方法均返回\n一个新数据表，原数据表不变\n（2）使用 append方法后\n（3）使用 concat方法后按行添加按列添加\n成绩单 .xlsx\n【例13.7】Pandas筛选示例 2\n11【例13.7】期中考试结束了，已知 12位同学的 数学成绩和语文成绩，分别存储在两\n个列表中 。\n          数学成绩 : [50,75,89,66,92,73,84,99,59,69,92,87 ]\n          语文成绩 : [62,80,85,70,93,80,81,89,72,80,95,91 ]\n◆试筛选出数学成绩大于等于 90的行\n◆筛选出 90>数学成绩 >60的行\n◆筛选出语文成绩小于 80的行\n◆筛选出数学成绩和语文成绩均大于等于 90的学生，且 语文成绩列在前，数学成绩列在后\n◼问题：如何从一些记录 中筛选出某字段或某几个字段的 值符合筛选条件的记录？\n◼分析：显然这属于 按值过滤 ，采用方法一即可\n数据表 [数据表 [列名称 ]>=指定值 ] 格式【例13.7】的Python程序\n12……\n#1、创建二维数据表', metadata={}), 0.47849273681640625), (Document(page_content='【例】concat_result= pd.concat([df1, df2],axis=1) \n#将df2中的所有列添加到 df1的末尾未来 pandas版本可\n能移除该方法【例13.3】加入数据示例\n8【例13.3】加入数据。分别创建 两个二维数据表df1、df2，列索引为 学号、数学成绩 ，行\n索引分别为 0~3、4~7。\n（1）采用 append() 方法将df2中的所有行添加到 df1的末尾，得到新的数据表。\n（2）创建一个 二维数据表df3，包含 8行数据，列索引为 学号、语文成绩 ，行索引为 0~7。\n（3）使用concat方法将df3中的所有列添加到新 数据表的列末尾 ；结果写入Excel文件。\n+【例13.3】的Python程序\n9import pandas as pd\nimport numpy as np\ndata1={\'学号 \': [1001,1002,1003,1004], \' 数学成绩 \': [50,75,89,66]}\ndata2={\'学号 \': [1005,1006,1007,1008], \' 数学成绩 \': [92,73,84,99]}\ndf1 = pd.DataFrame (data1,index=[0,1,2,3]) \ndf2 = pd.DataFrame (data2,index=[4,5,6,7])\n#1、采用 append ()方法增加行\nappend_result= df1.append(df2 ) #append() 方法将 df2中的所有行 添加到 df1的末尾（列数应该相同）\nprint(" append_result ：","\\n",append_result )\nprint("df1 不变： ","\\n",df1)                    # 原数据表不变\nprint()\n ...

# %%
docs[1][1]
# Out:
# 0.35712718963623047

# %%
if docs[1][1] < 0.5:
    print("false")
# Out:
# false
